# %%
import pandas as pd

# %%
# reading and showing dataframe
df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# ## 1. Create Index
#
# This method is going to help us set a column as a new index.

# %%
import numpy as np
import random

# %%
# creating non repetitive values for the index
new_index = np.arange(0, 1000)

# index in a df doesn't allow duplicates, the values have to be different from each other
# So we created an new_index variable which is an array of integer numbers: [0, 1, 2, ..., 999]

# %%
# shuffling indexes so we can sort it later
random.shuffle(new_index)

# %%
# apparently nothing happened, but this new_index was shuffled
# i verified that the array of integers was shuffled with print(new_index)

# %%
# create a new column with new index
df_exams['new_index'] = new_index
df_exams.head()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 53         female        group B           bachelor's degree      standard
# 534        female        group C                some college      standard
# 346        female        group B             master's degree      standard
# 665          male        group A          associate's degree  free/reduced
# 214          male        group C                some college      standard
#
#           test preparation course  math score  reading score  writing score  \
# new_index
# 53                           none          72             72             74
# 534                     completed          69             90             88
# 346                          none          90             95             93
# 665                          none          47             57             44
# 214                          none          76             78             75
#
#            new_index
# new_index
# 53               221
# 534              182
# 346              764
# 665              622
# 214              586

# %% [markdown]
# ## 2. Set index

# %%
# setting new_index column as index
df_exams.set_index('new_index', inplace=True) 
df_exams
# the set index method creates a copy of the df with the new index. To update the 
# df we have to set the inplace parameter to True.
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 221        female        group B           bachelor's degree      standard
# 182        female        group C                some college      standard
# 764        female        group B             master's degree      standard
# 622          male        group A          associate's degree  free/reduced
# 586          male        group C                some college      standard
# ...           ...            ...                         ...           ...
# 869        female        group E             master's degree      standard
# 930          male        group C                 high school  free/reduced
# 354        female        group C                 high school  free/reduced
# 315        female        group D                some college      standard
# 707        female        group D                some college  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 221                          none          72             72             74
# 182                     completed          69             90             88
# 764                          none          90             95             93
# 622                          none          47             57             44
# 586                          none          76             78             75
# ...                           ...         ...            ...            ...
# 869                     completed          88             99             95
# 930                          none          62             55             55
# 354                     completed          59             71             65
# 315                     completed          68             78             77
# 707                          none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## 3. Sort Index
#
# This method is going to help us sort the index.

# %%
# sort dataframe by new_index
df_exams.sort_index()
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0            male        group A            some high school      standard
# 1          female        group D                some college  free/reduced
# 2          female        group D            some high school      standard
# 3            male        group D          associate's degree  free/reduced
# 4          female        group C                some college  free/reduced
# ...           ...            ...                         ...           ...
# 995          male        group B            some high school      standard
# 996        female        group C            some high school      standard
# 997        female        group C          associate's degree      standard
# 998          male        group B          associate's degree      standard
# 999        female        group C           bachelor's degree  free/reduced
#
#           test preparation course  math score  reading score  writing score
# new_index
# 0                            none          51             31             36
# 1                            none          64             74             75
# 2                            none          59             72             80
# 3                            none          66             62             64
# 4                       completed          42             66             69
# ...                           ...         ...            ...            ...
# 995                          none          74             63             57
# 996                          none          65             69             76
# 997                     completed          62             76             80
# 998                          none          81             73             72
# 999                          none          43             62             61
#
# [1000 rows x 8 columns]

# %%
# As we can see here, now it's sorted ascending. So from 0 to 999.

# %%
# sort descending by index
df_exams.sort_index(ascending=False, inplace=True)

# %%
df_exams
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 999        female        group C           bachelor's degree  free/reduced
# 998          male        group B          associate's degree      standard
# 997        female        group C          associate's degree      standard
# 996        female        group C            some high school      standard
# 995          male        group B            some high school      standard
# ...           ...            ...                         ...           ...
# 4          female        group C                some college  free/reduced
# 3            male        group D          associate's degree  free/reduced
# 2          female        group D            some high school      standard
# 1          female        group D                some college  free/reduced
# 0            male        group A            some high school      standard
#
#           test preparation course  math score  reading score  writing score
# new_index
# 999                          none          43             62             61
# 998                          none          81             73             72
# 997                     completed          62             76             80
# 996                          none          65             69             76
# 995                          none          74             63             57
# ...                           ...         ...            ...            ...
# 4                       completed          42             66             69
# 3                            none          66             62             64
# 2                            none          59             72             80
# 1                            none          64             74             75
# 0                            none          51             31             36
#
# [1000 rows x 8 columns]

# %%
# Given that we set inplace to True all the changes were saved

# %%
# And that's how the set index and sort index methods works in Pandas.
